# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 1. Load Data
disparity = pd.read_csv("total_line_disparity_new.csv")
win_probs = pd.read_csv("win_probs.csv")

# %%
# 2. Extract and average team ratings from win_probs to represent 'Team Strength'
home_ratings = win_probs[['home_team', 'home_rating']].rename(columns={'home_team': 'team', 'home_rating': 'rating'})
away_ratings = win_probs[['away_team', 'away_rating']].rename(columns={'away_team': 'team', 'away_rating': 'rating'})
team_ratings = pd.concat([home_ratings, away_ratings]).groupby('team').mean().reset_index()

# 3. Merge Datasets
merged = pd.merge(disparity, team_ratings, on='team')

# %%
merged
# Out:
#             team     First  Secondary  disparity_log_ratio       rating
# 0     kazakhstan  0.576809   1.030707             0.580489   931.452455
# 1      indonesia  0.636998   1.042970             0.493061  1309.576204
# 2    switzerland  0.601435   0.959917             0.467529  1124.372511
# 3    philippines  0.642893   0.993522             0.435279  1356.351127
# 4       mongolia  0.573607   0.881259             0.429408   828.953276
# 5        germany  0.762485   1.143216             0.405017  1493.843136
# 6    netherlands  0.742256   1.108823             0.401361  1845.019820
# 7        vietnam  0.710080   1.049971             0.391140  1155.864376
# 8       ethiopia  0.782581   1.124605             0.362589  1447.427337
# 9        morocco  0.809352   1.128622             0.332519  1577.200553
# 10           uae  0.690398   0.938652             0.307176   975.072693
# 11      thailand  0.987312   1.334150             0.301064  2033.648378
# 12        canada  0.821958   1.108385             0.298970  1156.883880
# 13        france  0.892172   1.185404             0.284181  1625.537578
# 14        panama  0.883307   1.167994             0.279371  1806.518542
# 15         china  0.874370   1.155538             0.278818  1857.319345
# 16        mexico  0.890527   1.175735             0.277835  1426.781670
# 17        brazil  0.937010   1.226061             0.268867  2084.791208
# 18            uk  0.954053   1.235880             0.258820  1731.405625
# 19          peru  0.828832   1.069949             0.255349  1737.441202
# 20        serbia  0.979934   1.254880             0.247309  1592.066960
# 21   new_zealand  0.847741   1.084390             0.246197  1512.353412
# 22          oman  0.877879   1.105180             0.230254  1136.694830
# 23         india  0.849612   1.059688             0.220951  1555.032040
# 24     singapore  0.925834   1.136010             0.204582  1270.844099
# 25      pakistan  1.042496   1.267605             0.195511  1829.819918
# 26  saudi_arabia  0.778986   0.941382             0.189355  1201.163491
# 27        rwanda  0.818788   0.978788             0.178490   918.542340
# 28   south_korea  0.954112   1.139365             0.177446  1498.597400
# 29     guatemala  0.976252   1.092836             0.112810  1613.930497
# 30           usa  0.962620   1.066495             0.102475  1148.971866
# 31       iceland  0.907004   0.979066             0.076453  1489.302117

# %%
# 4. Set Plot Style
plt.figure(figsize=(10, 6), dpi=300)
sns.set_theme(style="whitegrid", context="talk")

# 5. Create Scatter Plot with Trendline
ax = sns.regplot(
    data=merged, 
    y='disparity_log_ratio', 
    x='rating', 
    scatter_kws={'alpha': 0.6, 'color': '#2C3E50', 'edgecolor': 'w', 's': 70},
    line_kws={'color': '#E74C3C', 'linewidth': 3}
)

# 6. Customize Labels and Titles
plt.title("Does a Balanced Attack Matter?\n", fontsize=18, weight='bold', loc='left')
#plt.suptitle("No clear link found between offensive line disparity and overall team strength", fontsize=13, x=0.125, y=0.90, ha='left')

plt.ylabel("Log Line Disparity Ratio\nabs(ln(1st Line xG/60 ÷ 2nd Line xG/60))\n← More Evenly Matched | Top-Heavy →", fontsize=12)
plt.xlabel("Team Strength (Elo Rating)", fontsize=12)

# 7. Add Caption
plt.figtext(0.90, 0.01, "Source: WHL Line Disparity & Win Probabilities Data", ha="right", fontsize=9, color="gray", style="italic")

# 8. Clean up and Save
sns.despine(left=True, bottom=True)
plt.tight_layout(rect=[0, 0.05, 1, 0.92]) 
#plt.show()

file_name = "phase1c_disparityvssuccess.png"
plt.savefig(file_name, bbox_inches="tight")
plt.close()
