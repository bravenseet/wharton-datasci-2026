# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 1. Load Data
disparity = pd.read_csv("total_line_disparity.csv")
win_probs = pd.read_csv("win_probs.csv")

# %%
# 2. Extract and average team ratings from win_probs to represent 'Team Strength'
home_ratings = win_probs[['home_team', 'home_rating']].rename(columns={'home_team': 'team', 'home_rating': 'rating'})
away_ratings = win_probs[['away_team', 'away_rating']].rename(columns={'away_team': 'team', 'away_rating': 'rating'})
team_ratings = pd.concat([home_ratings, away_ratings]).groupby('team').mean().reset_index()

# 3. Merge Datasets
merged = pd.merge(disparity, team_ratings, on='team')

# %%
merged
# Out:
#             team  first_line_xg60  secondary_xg60  disparity_ratio  \
# 0            usa         0.045368        0.033254         1.364308
# 1   saudi_arabia         0.037173        0.027277         1.362785
# 2      guatemala         0.046454        0.034268         1.355610
# 3            uae         0.033041        0.024380         1.355225
# 4         france         0.042378        0.031625         1.340006
# 5        iceland         0.042903        0.032402         1.324077
# 6      singapore         0.043570        0.034717         1.255006
# 7    new_zealand         0.040293        0.032889         1.225118
# 8         panama         0.042197        0.035195         1.198958
# 9           peru         0.039546        0.033015         1.197819
# 10        rwanda         0.038729        0.032460         1.193136
# 11         india         0.040138        0.034401         1.166766
# 12            uk         0.045140        0.038720         1.165818
# 13   netherlands         0.035581        0.031946         1.113780
# 14        serbia         0.046560        0.041894         1.111369
# 15   south_korea         0.045149        0.040798         1.106631
# 16        mexico         0.042526        0.040153         1.059108
# 17         china         0.041600        0.039550         1.051813
# 18      mongolia         0.027378        0.026186         1.045492
# 19      pakistan         0.049429        0.047763         1.034877
# 20        canada         0.039392        0.038978         1.010626
# 21    kazakhstan         0.027811        0.027766         1.001598
# 22   philippines         0.030574        0.030562         1.000397
# 23       morocco         0.038484        0.038523         0.998993
# 24          oman         0.041002        0.041737         0.982381
# 25        brazil         0.044708        0.045621         0.979974
# 26      thailand         0.047150        0.048263         0.976936
# 27     indonesia         0.030061        0.031312         0.960029
# 28       germany         0.036130        0.037793         0.956004
# 29       vietnam         0.033424        0.035381         0.944681
# 30      ethiopia         0.036995        0.040846         0.905728
# 31   switzerland         0.028418        0.031968         0.888955
#
#          rating
# 0   1148.971866
# 1   1201.163491
# 2   1613.930497
# 3    975.072693
# 4   1625.537578
# 5   1489.302117
# 6   1270.844099
# 7   1512.353412
# 8   1806.518542
# 9   1737.441202
# 10   918.542340
# 11  1555.032040
# 12  1731.405625
# 13  1845.019820
# 14  1592.066960
# 15  1498.597400
# 16  1426.781670
# 17  1857.319345
# 18   828.953276
# 19  1829.819918
# 20  1156.883880
# 21   931.452455
# 22  1356.351127
# 23  1577.200553
# 24  1136.694830
# 25  2084.791208
# 26  2033.648378
# 27  1309.576204
# 28  1493.843136
# 29  1155.864376
# 30  1447.427337
# 31  1124.372511

# %%
# 4. Set Plot Style
plt.figure(figsize=(10, 6), dpi=300)
sns.set_theme(style="whitegrid", context="talk")

# 5. Create Scatter Plot with Trendline
ax = sns.regplot(
    data=merged, 
    x='disparity_ratio', 
    y='rating', 
    scatter_kws={'alpha': 0.6, 'color': '#2C3E50', 'edgecolor': 'w', 's': 70},
    line_kws={'color': '#E74C3C', 'linewidth': 3}
)

# 6. Customize Labels and Titles
plt.title("Does a Balanced Attack Matter?\n", fontsize=18, weight='bold', loc='left')
#plt.suptitle("No clear link found between offensive line disparity and overall team strength", fontsize=13, x=0.125, y=0.90, ha='left')

plt.xlabel("Line Disparity Ratio\n(1st Line xG/60 ÷ 2nd Line xG/60)\n← More Evenly Matched | Top-Heavy →", fontsize=12)
plt.ylabel("Team Strength (Elo Rating)", fontsize=12)

# 7. Add Caption
plt.figtext(0.90, 0.01, "Source: WHL Line Disparity & Win Probabilities Data", ha="right", fontsize=9, color="gray", style="italic")

# 8. Clean up and Save
sns.despine(left=True, bottom=True)
plt.tight_layout(rect=[0, 0.05, 1, 0.92]) 
#plt.show()

file_name = "phase1c_disparityvssuccess.png"
plt.savefig(file_name, bbox_inches="tight")
plt.close()
